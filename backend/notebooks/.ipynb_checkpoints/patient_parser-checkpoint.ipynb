# %%
from pdf2image import convert_from_path

# %%
import pytesseract

# %%
import numpy as np
import cv2

# %%
pages = convert_from_path('/Users/shikhabharati/Desktop/Python/medicalProject/backend/resources/patient_details/pd_1.pdf')
pages
# Out:
# [<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1867x2000>,
#  <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2000x1398>]

# %%
text = pytesseract.image_to_string(pages[0], lang = 'eng')
print(text)
# Out:
# 47/12/2020
#
# Patient Medical Record
#
# Patient Information Birth Date
# Kathy Crawford May 6 1972
# (737) 988-0851 Weight
# 9264 Ash Dr 95
# New York City, 10005 .
# United States Height:
# 190
# In Case of Emergency
# m _ eee ee
# Simeone Crawford 9266 Ash Dr
# New York City, New York, 10005
# Home phone United States
# (990) 375-4621
# Work phone
# Genera! Medical History
#
# Chicken Pox (Varicella):
#
# IMMUNE IMMUNE
# Have you had the Hepatitis B vaccination?
#
# No
# List any Medical Problems (asthma, seizures, headaches):
#
# Migraine

# %%
text = pytesseract.image_to_string(pages[1], lang = 'eng')
print(text)
# Out:
# pa
#
# ’ Name of Insurance Company:
#
# Random tnsuarance Company : 4789 Bollinger Rd
# Policy Number: _————————E7
#
# 7115207313 Expiry Date:
# 30 December 2020
# Do you have medical insurance?
#
# Yes
#
# Medical Insurance Details
#
# List any allergies:
#
# Peanuts
#
# List any medication taken regularly:
#
# Triptans

# %%
def preprocess_img(img):
    grayscale = cv2.cvtColor(np.array(img), cv2.COLOR_BGR2GRAY)
    resized_img = cv2.resize(grayscale, None, fx=1.5, fy = 1.5, interpolation = cv2.INTER_LINEAR)
    processed_img = cv2.adaptiveThreshold(resized_img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                         cv2.THRESH_BINARY, 71,15)
    return processed_img

# %%
from PIL import Image
img = preprocess_img(pages[0])
Image.fromarray(img).show()

# %%
pages[1]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2000x1398>

# %%
text = pytesseract.image_to_string(img, lang = 'eng')
print(text)
# Out:
# 17/12/2020
#
# Patient Medical Record
#
# Patient Information Birth Date
# Kathy Crawford May 6 1972
# (737) 988-0851 Weight’
# 9264 Ash Dr 95
# New York City, 10005 '
# United States Height:
# 190
# In Casc of Emergency
# ee ee
# Simeone Crawford 9266 Ash Dr
# 4 New York City, New York, 10005
# ome phone United States
# (990) 375-4621
# Work phone
# Genera! Medical History
# 2
#
# i
# nee en remmrmnney ne a
#
# Chicken Pox (Varicella): Measies:
#
# IMMUNE IMMUNE
#
# Have you had the Hepatitis B vaccination?
#
# No
#
# List any Medical Problems (asthma, seizures, headaches):
#
# Migraine

# %%
text = pytesseract.image_to_string(pages[1], lang = 'eng')
print(text)
# Out:
# pa
#
# ’ Name of Insurance Company:
#
# Random tnsuarance Company : 4789 Bollinger Rd
# Policy Number: _————————E7
#
# 7115207313 Expiry Date:
# 30 December 2020
# Do you have medical insurance?
#
# Yes
#
# Medical Insurance Details
#
# List any allergies:
#
# Peanuts
#
# List any medication taken regularly:
#
# Triptans
